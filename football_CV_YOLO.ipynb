# %% [markdown]
# # Autorisation d'accès à votre Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 14327 (delta 0), reused 0 (delta 0), pack-reused 14326
# Receiving objects: 100% (14327/14327), 12.86 MiB | 18.65 MiB/s, done.
# Resolving deltas: 100% (9776/9776), done.

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 22 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# ...

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1424:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2020-10-05 23:58:22--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   241KB/s    in 15m 7s
#
# 2020-10-06 00:13:29 (267 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev libdc1394-22 libdc1394-22-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# libvorbis-dev is already the newest version (1.3.5-4.2).
# libvorbis-dev set to manually installed.
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python3-numpy set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# libdc1394-22 is already the newest version (2.2.5-1).
# libdc1394-22 set to manually installed.
# libdc1394-22-dev is already the newest version (2.2.5-1).
# libdc1394-22-dev set to manually installed.
# libtbb-dev is already the newest version (2017~U7-8).
# libtbb-dev set to manually installed.
# libtiff5-dev is already the newest version (4.0.9-5ubuntu0.3).
# libtiff5-dev set to manually installed.
# ...

# %% [markdown]
# N'oubliez pas de mettre le fichier test *baratl.mp4* dans le dossier *darknet* !

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show baratl.mp4 -i 0 -out_filename output1.avi -thresh 0.7
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
# FPS:32.7 	 AVG_FPS:33.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 96%
# person: 95%
# person: 94%
# person: 90%
# person: 90%
# person: 89%
# person: 88%
# person: 84%
# person: 83%
# person: 77%
# person: 74%
# person: 73%
# person: 72%
#
# FPS:32.8 	 AVG_FPS:33.5
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 96%
# person: 92%
# person: 91%
# person: 88%
# person: 86%
# person: 85%
# person: 84%
# person: 76%
# person: 74%
# person: 73%
# person: 73%
# person: 72%
#
# FPS:32.8 	 AVG_FPS:33.5
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 95%
# person: 93%
# person: 90%
# person: 88%
# person: 82%
# person: 77%
# person: 75%
# person: 74%
# person: 73%
# person: 73%
#
# FPS:32.9 	 AVG_FPS:33.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 98%
# person: 96%
# person: 96%
# person: 92%
# person: 92%
# person: 88%
# person: 87%
# person: 74%
# person: 73%
#
# ...

# %%
from google.colab import files
files.download('output1.avi')
